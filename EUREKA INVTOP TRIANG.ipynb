# %%
# %pylab inline
import sys
# sys.path.append("/Users/becqg/Documents/code/Robinson")
sys.path.append("C:\Users\Guillaume\Documents\projets\code\Robinson")
import ER
import imp
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h2> EUREKA</h2>

# %%
imp.reload(ER)
LR = 2
R = numpy.array([2.5625, -1.25])
G = numpy.array([-1.25, 0])
F = numpy.empty((LR, ))
A = numpy.empty((LR, ))
(F, A) = ER.EUREKA(LR, R, G, F, A)
print(F)
print(A)
# Out:
# (0, 1, 1)
# (2, 1, array([-0.64, -0.31]))
# [-0.6401249  -0.31225605]
# [ 1.          0.48780488]

# %%
V = 2.5625
D = -1.25
A1 = 1.
F1 = -1.25 / 2.5625
print(F1)
Q = F1 * (-1.25)
print(Q)
A2 = -D / V
print(A2)
V += A2 * D
F2 = (0 - Q) / V
print(F2)
F1 = F1 + F2 * A2
print(F1)
# Out:
# -0.487804878049
# 0.609756097561
# 0.487804878049
# -0.312256049961
# -0.64012490242

# %%
LR = 2
R = numpy.array([10., 4])
G = numpy.array([2., 0])
F = numpy.empty((LR, ))
A = numpy.empty((LR, ))
(F, A) = ER.EUREKA(LR, R, G, F, A)
print(F)
print(A)
# Out:
# (0, 1, 1)
# (2, 1, array([ 0.24, -0.1 ]))
# [ 0.23809524 -0.0952381 ]
# [ 1.  -0.4]

# %% [markdown]
# <h2> INVTOP </h2>

# %%
imp.reload(ER)
LR = 5
R = numpy.array([10.0, 4.0, -1.0, -4.0, -4.0])
F = numpy.empty(LR)
A = numpy.empty(LR)
G = numpy.array([1., 0., 0., 0., 0.])
(F, A) = ER.EUREKA(LR, R, G, F, A)
print(F)
print(A)

V = 10.0
D = 4.0
A1 = 1.
F1 = 1. / V
print(F1)
Q = F1 * (4.0)
print(Q)
# IF(LR.EQ.1) RETURN
# L = 2
A2 = -D / V
print(A2)
# IF(L.EQ.2) GO TO 2
# 2
V += A2 * D
F2 = (0.0 - Q) / V
# L3 = L - 1 = 1
# J = 1
# K = L - J + 1 = 2
F1 += F2 * A2
print("F1: {0}".format(F1))
print("F2: {0}".format(F2))
D = 0.0
Q = 0.0
# I = 1
# K = L - I + 2 = 3
D += A1 * (-1.)
Q += F1 * (-1.)
# I = 2
# K = 2
D += A2 * 4.0
Q += F2 * 4.0
# L = 3
A3 = -D / V
print(A3)
# IF (L.EQ.2) GO TO 2
# L1 = (L - 2) / 2 = 0
# L2 = L1 + 1 = 1
# IF(L2.LT.2) GO TO 5
# 5
# IF(2*L1.EQ.L-2) GO TO 2
A2 += A3 * A2
print(A2)
V += A3 * D
F3 = (0. - Q) / V
# L3 = L - 1 = 2
# J = 1
# K = L - J + 1 = 3
F1 += F3 * A3
# J = 2
# K = 2
F2 += F3 * A2
print("F1: {0}".format(F1))
print("F2: {0}".format(F2))
print("F3: {0}".format(F3))
D = 0.0
Q = 0.0
# I = 1
# K = L - I + 2 = 4
D += A1 * (-4.0)
Q += F1 * (-4.0)
# I = 2
# K = L - I + 2 = 3
D += A2 * (-1.0)
Q += F2 * (-1.0)
# I = 3
# K = L - I + 2 = 2
D += A3 * (4.0)
Q += F3 * (4.0)
# L = 4
A4 = -D / V
# L1 = (L - 2) / 2 = 1
# L2 = L1 + 1 = 2
# IF(L2.LT.2) GO TO 5
# J = 2
HOLD = A2
# K = L - J + 1 = 3
A2 += A4 * A3
A3 += A4 * HOLD
# IF(2*L1.EQ.L-2) GO TO 2
# 2
V += A4 * D
F4 = (0. - Q) / V
# L3 = L - 1 = 3
# J = 1
# K = L - J + 1 = 4
F1 += F4 * A4
# J = 2
# K = L - J + 1 = 3
F2 += F4 * A3
# J = 3
# K = L - J + 1 = 2
F3 += F4 * A2
print("F1: {0}".format(F1))
print("F2: {0}".format(F2))
print("F3: {0}".format(F3))
print("F4: {0}".format(F4))
D = 0.0
Q = 0.0
# I = 1
# K = L - I + 2 = 5
D += A1 * (-4.0)
Q += F1 * (-4.0)
# I = 2
# K = L - I + 2 = 4
D += A2 * (-4.0)
Q += F2 * (-4.0)
# I = 3
# K = L - I + 2 = 3
D += A3 * (-1.0)
Q += F3 * (-1.0)
# I = 4
# K = L - I + 2 = 2
D += A4 * (4.0)
Q += F4 * (4.0)
# L = 5
A5 = -D / V
# L1 = (L - 2) / 2 = 1
# L2 = L1 + 1 = 2
# J = 2
HOLD = A2
# K = L - J + 1 = 4
A2 += A5 * A4
A4 += A5 * HOLD
A3 += A5 * A3
V += A5 * D
F5 = (0. - Q) / V
# L3 = L - 1 = 4
# J = 1
# K = L - J + 1 = 5
F1 += F5 * A5
# J = 2
# K = L - J + 1 = 4
F2 += F5 * A4
# J = 3
# K = L - J + 1 = 3
F3 += F5 * A3
# J = 4
# K = L - J + 1 = 2
F4 += F5 * A2
print("F1: {0}".format(F1))
print("F2: {0}".format(F2))
print("F3: {0}".format(F3))
print("F4: {0}".format(F4))
print("F5: {0}".format(F5))
# Out:
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([ 0.119 , -0.0476,  0.    ,  0.    ,  0.    ]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('L2, L, L2', 1, 2, 1)
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([ 0.1317, -0.069 ,  0.0408,  0.    ,  0.    ]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('<< J, L, K', 1, 3, 2)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([ 0.1442, -0.0624,  0.0224,  0.0425,  0.    ]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# ('<< J, L, K', 1, 4, 3)
# even
# ('L2, L, L2', 2, 4, 2)
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([ 0.149 , -0.0566,  0.0273,  0.0323,  0.0268]))
# [ 0.1489899  -0.05656566  0.02727273  0.03232323  0.02676768]
# [ 1.         -0.37966102  0.18305085  0.21694915  0.17966102]
# 0.1
# 0.4
# -0.4
# F1: 0.119047619048
# F2: -0.047619047619
# 0.309523809524
# -0.52380952381
# F1: 0.131661442006
# F2: -0.0689655172414
# F3: 0.0407523510972
# F1: 0.14418079096
# F2: -0.0623728813559
# F3: 0.0223728813559
# F4: 0.0424858757062
# F1: 0.14898989899
# F2: -0.0565656565657
# F3: 0.0272727272727
# F4: 0.0323232323232
# F5: 0.0267676767677

# %%
imp.reload(ER)
LR = 5
R = numpy.array([10.0, 4.0, -1.0, -4.0, -4.0])
Q = numpy.empty((LR * LR, ))
SPACE = numpy.empty((2 * LR, ))
(Q, SPACE) = ER.INVTOP(LR, R, Q, SPACE)
print(Q)
print(SPACE)
# Out:
# K: 0
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([ 0.119 , -0.0476,  0.    ,  0.    ,  0.    ]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('L2,L,L2', 1, 2, 1)
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([ 0.1317, -0.069 ,  0.0408,  0.    ,  0.    ]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('<< J, L, K', 1, 3, 2)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([ 0.1442, -0.0624,  0.0224,  0.0425,  0.    ]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# ('<< J, L, K', 1, 4, 3)
# even
# ('L2,L,L2', 2, 4, 2)
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([ 0.149 , -0.0566,  0.0273,  0.0323,  0.0268]))
# K: 1
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([-0.0476,  0.119 ,  0.    ,  0.    ,  0.    ]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('L2,L,L2', 1, 2, 1)
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([-0.069 ,  0.1552, -0.069 ,  0.    ,  0.    ]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('<< J, L, K', 1, 3, 2)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([-0.0624,  0.1586, -0.0786,  0.0224,  0.    ]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# ('<< J, L, K', 1, 4, 3)
# even
# ('L2,L,L2', 2, 4, 2)
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([-0.0566,  0.1657, -0.0727,  0.0101,  0.0323]))
# K: 2
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('L2,L,L2', 1, 2, 1)
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([ 0.0408, -0.069 ,  0.1317,  0.    ,  0.    ]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('<< J, L, K', 1, 3, 2)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([ 0.0224, -0.0786,  0.1586, -0.0624,  0.    ]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# ('<< J, L, K', 1, 4, 3)
# even
# ('L2,L,L2', 2, 4, 2)
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([ 0.0273, -0.0727,  0.1636, -0.0727,  0.0273]))
# K: 3
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('L2,L,L2', 1, 2, 1)
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('<< J, L, K', 1, 3, 2)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([ 0.0425,  0.0224, -0.0624,  0.1442,  0.    ]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# ('<< J, L, K', 1, 4, 3)
# even
# ('L2,L,L2', 2, 4, 2)
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([ 0.0323,  0.0101, -0.0727,  0.1657, -0.0566]))
# K: 4
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('L2,L,L2', 1, 2, 1)
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('<< J, L, K', 1, 3, 2)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# ('<< J, L, K', 1, 4, 3)
# even
# ('L2,L,L2', 2, 4, 2)
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([ 0.0268,  0.0323,  0.0273, -0.0566,  0.149 ]))
# [ 0.1489899  -0.05656566  0.02727273  0.03232323  0.02676768 -0.05656566
#   0.16565657 -0.07272727  0.01010101  0.03232323  0.02727273 -0.07272727
#   0.16363636 -0.07272727  0.02727273  0.03232323  0.01010101 -0.07272727
#   0.16565657 -0.05656566  0.02676768  0.03232323  0.02727273 -0.05656566
#   0.1489899 ]
# [ 0.          0.          0.          0.          1.          1.
#  -0.37966102  0.18305085  0.21694915  0.17966102]

# %%
imp.reload(ER)
LR = 5
R = numpy.array([10.0, 4.0, 1.0, 4.0, 4.0])
Q = numpy.empty((LR * LR, ))
SPACE = numpy.empty((2 * LR, ))
(Q, SPACE) = ER.INVTOP(LR, R, Q, SPACE)
print(numpy.round(Q, 5))
print(numpy.round(SPACE, 5))
# Out:
# K: 0
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([ 0.119 , -0.0476,  0.    ,  0.    ,  0.    ]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([ 0.1197, -0.051 ,  0.0086,  0.    ,  0.    ]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([ 0.1528, -0.0697,  0.0394, -0.0708,  0.    ]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# even
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([ 0.1542, -0.0644,  0.0358, -0.0654, -0.0137]))
# K: 1
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([-0.0476,  0.119 ,  0.    ,  0.    ,  0.    ]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([-0.0515,  0.1396, -0.0513,  0.    ,  0.    ]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([-0.071 ,  0.1505, -0.0694,  0.0416,  0.    ]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# even
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([-0.0646,  0.1751, -0.0864,  0.0666, -0.0642]))
# K: 2
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([ 0.0092, -0.0479,  0.1197,  0.    ,  0.    ]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([ 0.0427, -0.0668,  0.1509, -0.0716,  0.    ]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# even
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([ 0.0391, -0.0805,  0.1604, -0.0856,  0.0359]))
# K: 3
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([-0.0716,  0.0404, -0.0668,  0.1532,  0.    ]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# even
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([-0.0651,  0.0653, -0.0839,  0.1785, -0.0651]))
# K: 4
# ---------------
# ('L', 1)
# ('J, L, K', 0, 1, 1)
# (5, 1, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 2)
# ('I, K', 1, 1)
# ---------------
# ('L', 2)
# even
# ('J, L, K', 0, 2, 2)
# ('J, L, K', 1, 2, 1)
# (5, 2, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 3)
# ('I, K', 1, 2)
# ('I, K', 2, 1)
# ---------------
# ('L', 3)
# ('J, L, K', 0, 3, 3)
# ('J, L, K', 1, 3, 2)
# ('J, L, K', 2, 3, 1)
# (5, 3, array([ 0.,  0.,  0.,  0.,  0.]))
# ('I, K', 0, 4)
# ('I, K', 1, 3)
# ('I, K', 2, 2)
# ('I, K', 3, 1)
# ---------------
# ('L', 4)
# even
# ('J, L, K', 0, 4, 4)
# ('J, L, K', 1, 4, 3)
# ('J, L, K', 2, 4, 2)
# ('J, L, K', 3, 4, 1)
# (5, 4, array([-0.0154, -0.0591,  0.0408, -0.0602,  0.1547]))
# [ 0.15416 -0.06445  0.03577 -0.06543 -0.01373 -0.06462  0.17508 -0.08638
#   0.06665 -0.06425  0.03908 -0.08047  0.16038 -0.0856   0.0359  -0.06514
#   0.06525 -0.08393  0.17855 -0.06514 -0.01541 -0.05909  0.04078 -0.06022
#   0.15473]
# [ 0.       0.       0.       0.       1.       1.      -0.38921  0.26356
#  -0.38192 -0.0996 ]

# %% [markdown]
# <h2> TRIANG </h2>

# %%
imp.reload(ER)
N = 2
TOP = numpy.array([64, -48, -48, 37])
S = numpy.empty((N * N, ))
SPACE = numpy.empty((N * N, ))
(S, SPACE) = ER.TRIANG(N, TOP, S, SPACE)
print(S, SPACE)
# Out:
# (array([ 8.,  0., -6.,  1.]), array([  0.00000000e+000,   3.60000000e+001,   2.14984181e-314,
#          2.12343416e-314]))

# %%
imp.reload(ER)
N = 2
TOP = numpy.array([64, -48, -48, 37], "complex")
S = numpy.empty((N * N, ), "complex")
SPACE = numpy.empty((N * N, ), "complex")
(S, SPACE) = ER.TRIANG_CPLX(N, TOP, S, SPACE)
print(S, SPACE)
# Out:
# (array([ 8.+0.j,  0.+0.j, -6.+0.j,  1.+0.j]), array([  0.00000000e+000 +0.00000000e+000j,
#          3.60000000e+001 +0.00000000e+000j,
#          2.23958943e-314 +2.18483186e-314j,
#          2.12358783e-314 +0.00000000e+000j]))

# %%
A = numpy.array([[64, -48], [-48, 37]])
print(A)
print(numpy.linalg.cholesky(A))
# Out:
# [[ 64 -48]
#  [-48  37]]
# [[ 8.  0.]
#  [-6.  1.]]
