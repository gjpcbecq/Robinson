# %%
# %pylab inline
import sys
# sys.path.append("/Users/becqg/Documents/code/Robinson")
sys.path.append("C:\Users\Guillaume\Documents\projets\code\Robinson")
import ER
import imp
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h2> POLYEV</h2>

# %%
imp.reload(ER)
LA = 3
A = numpy.array([3., 2., 1.])
Z = complex(1, 1.0)
AZ = numpy.empty((LA))
AZ = ER.POLYEV(3, A, Z, AZ) 
print(AZ)

# %% [markdown]
# <h2>POMAIN</h2>
# p.162

# %%
imp.reload(ER)
N = 2
LA = 3
A = numpy.array([1, 0, 0, 1, -3, 14, 21, 1, 2, 5, -6, 14])
LADJ = (N - 1) * (LA - 1) + 1
LDET = N * (LA - 1) + 1
ADJ = empty(N * N * LADJ)
P = empty(N * LDET)
DET = empty(LDET)
S = empty(N * N * LDET)
(ADJ, P, DET, S) = ER.POMAIN(N, LA, A, ADJ, P, DET, S)
print("ADJ", ADJ)
print("P", P)
print("DET", DET)
# Out:
# ('ADJ', array([  1.-0.j,  -0.+0.j,  -0.+0.j,   1.-0.j,   1.-0.j, -14.+0.j,
#        -21.+0.j,  -3.+0.j,  14.-0.j,  -5.+0.j,   6.-0.j,   2.-0.j]))
# ('P', array([   2.+0.j,   -1.+0.j,   -2.+0.j,    2.+0.j,   16.+0.j,  281.+0.j,
#          61.+0.j,   61.+0.j,  -58.+0.j,  -58.+0.j]))
# ('DET', array([   1.-0.j,   -2.+0.j, -281.+0.j,  -61.+0.j,   58.-0.j]))

# %% [markdown]
# <h2> BRAINY </h2>
# p. 154

# %%
NRA = 2
NCA = 2
LA = 3
A = numpy.array([0, 1, 0, -1, 2, 0, 1, 1, 1, 1, 0, 0], "float")
NRB = 2
NCB = 2
LB = 3
B = numpy.array([0, 1, 0, 0, 0, 1, 1, 1, 1, 0, 1, 0], "float")
C = ()
C = ER.BRAINY(NRA, NCA, LA, A, NRB, NCB, LB, B, C)
print(C)
C = ER.BRAINY(NRB, NCB, LB, B, NRA, NCA, LA, A, C)
print(C)
# Out:
# [ 0. -1.  0.  0.  1.  0.  0.  0.  1.  2.  3.  2.  2.  0.  3.  1.  1.  1.
#   1.  1.]
# [ 0.  0.  0.  0.  1.  3. -1.  0.  1.  3.  0.  2.  3.  2.  2.  0.  2.  0.
#   0.  0.]

# %% [markdown]
# <h2> POLRT </h2>
# p. 35

# %%
imp.reload(ER)
XCOF = numpy.array([36., 0, -13, 0, 1])
M = 4
COF = numpy.empty(M + 1)
(ROOTR, ROOTI, IER) = ([], [], [])
(COF, ROOTR, ROOTI, IER) = ER.POLRT(XCOF, COF, M, ROOTR, ROOTI, IER)
print(COF, ROOTR, ROOTI, IER)
# Out:
# (array([  1.,   0.,  -4.,  12.,  36.]), array([-3.,  3., -2.,  2.]), array([ 0.,  0.,  0.,  0.]), 0)

# %%
imp.reload(ER)
XCOF = numpy.array([83, -278., 720, -238, 120])
M = 4
COF = numpy.empty(M + 1)
(ROOTR, ROOTI, IER) = ([], [], [])
(COF, ROOTR, ROOTI, IER) = ER.POLRT(XCOF, COF, M, ROOTR, ROOTI, IER)
print(COF, ROOTR, ROOTI, IER)
# Out:
# (array([  1.20000000e+02,  -5.68434189e-14,   6.27718661e+02,
#         -2.78000000e+02,   8.30000000e+01]), array([ 0.20146262,  0.20146262,  0.79020404,  0.79020404]), array([-0.30271712,  0.30271712, -2.14629132,  2.14629132]), 0)

# %% [markdown]
# ___
# test pas à pas sur le premier exemple pour débugguer

# %%
imp.reload(ER)

XCOF = [36., 0, -13, 0, 1]
COF = [0., 0, 0, 0, 0]
IFIT = 0
N = M = 4
IER = 0
IER = 1
NX = N
NXX = N + 1
N2 = 1
KJ1 = N + 1
print("COF: ", COF)
for L in range(1, KJ1+1): 
    MT = KJ1 - L + 1
    COF[MT-1] = XCOF[L-1]
print("COF: ", COF)
ROOTI = zeros(4)
ROOTR = zeros(4)


print("__________________________________________________")
XO = 0.00500101
YO = 0.01000101
IN = 0
X = XO
XO = -10.0 * YO
YO = -10.0 * X
X = XO
Y = YO
ICT = 0
IN = IN + 1
while (ICT < 500): 
    UX = 0.0
    UY = 0.0
    V = 0.0
    YT = 0.0
    XT = 1.0
    U = COF[N + 1 - 1]
    for I in range(1, N + 1): 
        L = N - I + 1
        XT2 = X * XT - Y * YT
        YT2 = X * YT + Y * XT
        U = U + COF[L - 1] * XT2
        V = V + COF[L - 1] * YT2
        FI = I
        UX = UX + FI * XT * COF[L - 1]
        UY = UY - FI * YT * COF[L - 1]
        XT = XT2
        YT = YT2
    SUMSQ = UX * UX + UY * UY
#    print(SUMSQ)
#    print(X, Y)
    if (SUMSQ == 0): 
        break
    DX = (V * UY - U * UX) / SUMSQ
    X = X + DX
    DY = -(U * UY + V * UX) / SUMSQ
    Y = Y + DY
    if (abs(DY) + abs(DX) < 1e-5): 
        break
    ICT = ICT + 1
print("COF, XCOF: ", COF, XCOF)
for L in range(1, NXX + 1): 
    MT = KJ1 - L + 1
    print("L, MT: ", L, MT)
    TEMP = XCOF[MT - 1]
    XCOF[MT - 1] = COF[L - 1]
    COF[L - 1] = TEMP
print("COF, XCOF: ", COF, XCOF)
ITEMP = N
N = NX
NX = ITEMP
print(IFIT)
IFIT = 1
XPR = X
YPR = Y
while ICT < 500: 
    UX = 0.0
    UY = 0.0
    V = 0.0
    YT = 0.0
    XT = 1.0
    U = COF[N + 1 - 1]
    for I in range(1, N + 1): 
        L = N - I + 1
        XT2 = X * XT - Y * YT
        YT2 = X * YT + Y * XT
        U = U + COF[L - 1] * XT2
        V = V + COF[L - 1] * YT2
        FI = I
        UX = UX + FI * XT * COF[L - 1]
        UY = UY - FI * YT * COF[L - 1]
        XT = XT2
        YT = YT2
    SUMSQ = UX * UX + UY * UY
    if (SUMSQ == 0): 
        break
    DX = (V * UY - U * UX) / SUMSQ
    X = X + DX
    DY = -(U * UY + V * UX) / SUMSQ
    Y = Y + DY
    if (abs(DY) + abs(DX) < 1e-5): 
        break
    ICT = ICT + 1
print("X, Y", X, Y)
print("IFIT", IFIT)
print("COF, XCOF: ", COF, XCOF)
for L in range(1, NXX + 1): 
    MT = KJ1 - L + 1
    print("L, MT: ", L, MT)
    TEMP = XCOF[MT - 1]
    XCOF[MT - 1] = COF[L - 1]
    COF[L - 1] = TEMP
print("COF, XCOF: ", COF, XCOF)
ITEMP = N
N = NX
NX = ITEMP
IFIT = 0
print(abs(Y / X) < 1e-4)
Y = 0.0
SUMSQ = 0.0
ALPHA = X
N = N - 1
COF[2 - 1] = COF[2 - 1] + ALPHA * COF[1 - 1]
for L in range(2, N + 1): 
    COF[L + 1 - 1] = COF[L + 1 - 1] + ALPHA * COF[L - 1] - SUMSQ * COF[L - 1]
print(COF)
ROOTI[N2 - 1] = Y
ROOTR[N2 - 1] = X
N2 = N2 + 1
print(SUMSQ, N)
print("ROOT: ", ROOTR, ROOTI)
print("__________________________________________________")
print("__________________________________________________")
XO = 0.00500101
YO = 0.01000101
IN = 0
X = XO
XO = -10.0 * YO
YO = -10.0 * X
X = XO
Y = YO
ICT = 0
IN = IN + 1
while (ICT < 500): 
    UX = 0.0
    UY = 0.0
    V = 0.0
    YT = 0.0
    XT = 1.0
    U = COF[N + 1 - 1]
    for I in range(1, N + 1): 
        L = N - I + 1
        XT2 = X * XT - Y * YT
        YT2 = X * YT + Y * XT
        U = U + COF[L - 1] * XT2
        V = V + COF[L - 1] * YT2
        FI = I
        UX = UX + FI * XT * COF[L - 1]
        UY = UY - FI * YT * COF[L - 1]
        XT = XT2
        YT = YT2
    SUMSQ = UX * UX + UY * UY
#    print(SUMSQ)
#    print(X, Y)
    if (SUMSQ == 0): 
        break
    DX = (V * UY - U * UX) / SUMSQ
    X = X + DX
    DY = -(U * UY + V * UX) / SUMSQ
    Y = Y + DY
    if (abs(DY) + abs(DX) < 1e-5): 
        break
    ICT = ICT + 1
print("COF, XCOF: ", COF, XCOF)
for L in range(1, NXX + 1): 
    MT = KJ1 - L + 1
    print("L, MT: ", L, MT)
    TEMP = XCOF[MT - 1]
    XCOF[MT - 1] = COF[L - 1]
    COF[L - 1] = TEMP
print("COF, XCOF: ", COF, XCOF)
ITEMP = N
N = NX
NX = ITEMP
print(IFIT)
IFIT = 1
XPR = X
YPR = Y
while ICT < 500: 
    UX = 0.0
    UY = 0.0
    V = 0.0
    YT = 0.0
    XT = 1.0
    U = COF[N + 1 - 1]
    for I in range(1, N + 1): 
        L = N - I + 1
        XT2 = X * XT - Y * YT
        YT2 = X * YT + Y * XT
        U = U + COF[L - 1] * XT2
        V = V + COF[L - 1] * YT2
        FI = I
        UX = UX + FI * XT * COF[L - 1]
        UY = UY - FI * YT * COF[L - 1]
        XT = XT2
        YT = YT2
    SUMSQ = UX * UX + UY * UY
    if (SUMSQ == 0): 
        break
    DX = (V * UY - U * UX) / SUMSQ
    X = X + DX
    DY = -(U * UY + V * UX) / SUMSQ
    Y = Y + DY
    if (abs(DY) + abs(DX) < 1e-5): 
        break
    ICT = ICT + 1
print("X, Y", X, Y)
print("IFIT", IFIT)
print("COF, XCOF: ", COF, XCOF)
for L in range(1, NXX + 1): 
    MT = KJ1 - L + 1
    print("L, MT: ", L, MT)
    TEMP = XCOF[MT - 1]
    XCOF[MT - 1] = COF[L - 1]
    COF[L - 1] = TEMP
print("COF, XCOF: ", COF, XCOF)
ITEMP = N
N = NX
NX = ITEMP
IFIT = 0
print(abs(Y / X) < 1e-4)
Y = 0.0
SUMSQ = 0.0
ALPHA = X
N = N - 1
COF[2 - 1] = COF[2 - 1] + ALPHA * COF[1 - 1]
for L in range(2, N + 1): 
    COF[L + 1 - 1] = COF[L + 1 - 1] + ALPHA * COF[L - 1] - SUMSQ * COF[L - 1]
print(COF)
ROOTI[N2 - 1] = Y
ROOTR[N2 - 1] = X
N2 = N2 + 1
print(SUMSQ, N)
print("ROOT: ", ROOTR, ROOTI)
print("__________________________________________________")
print("__________________________________________________")
XO = 0.00500101
YO = 0.01000101
IN = 0
X = XO
XO = -10.0 * YO
YO = -10.0 * X
X = XO
Y = YO
ICT = 0
IN = IN + 1
while (ICT < 500): 
    UX = 0.0
    UY = 0.0
    V = 0.0
    YT = 0.0
    XT = 1.0
    U = COF[N + 1 - 1]
    for I in range(1, N + 1): 
        L = N - I + 1
        XT2 = X * XT - Y * YT
        YT2 = X * YT + Y * XT
        U = U + COF[L - 1] * XT2
        V = V + COF[L - 1] * YT2
        FI = I
        UX = UX + FI * XT * COF[L - 1]
        UY = UY - FI * YT * COF[L - 1]
        XT = XT2
        YT = YT2
    SUMSQ = UX * UX + UY * UY
#    print(SUMSQ)
#    print(X, Y)
    if (SUMSQ == 0): 
        break
    DX = (V * UY - U * UX) / SUMSQ
    X = X + DX
    DY = -(U * UY + V * UX) / SUMSQ
    Y = Y + DY
    if (abs(DY) + abs(DX) < 1e-5): 
        break
    ICT = ICT + 1
print("COF, XCOF: ", COF, XCOF)
for L in range(1, NXX + 1): 
    MT = KJ1 - L + 1
    print("L, MT: ", L, MT)
    TEMP = XCOF[MT - 1]
    XCOF[MT - 1] = COF[L - 1]
    COF[L - 1] = TEMP
print("COF, XCOF: ", COF, XCOF)
ITEMP = N
N = NX
NX = ITEMP
print(IFIT)
IFIT = 1
XPR = X
YPR = Y
while ICT < 500: 
    UX = 0.0
    UY = 0.0
    V = 0.0
    YT = 0.0
    XT = 1.0
    U = COF[N + 1 - 1]
    for I in range(1, N + 1): 
        L = N - I + 1
        XT2 = X * XT - Y * YT
        YT2 = X * YT + Y * XT
        U = U + COF[L - 1] * XT2
        V = V + COF[L - 1] * YT2
        FI = I
        UX = UX + FI * XT * COF[L - 1]
        UY = UY - FI * YT * COF[L - 1]
        XT = XT2
        YT = YT2
    SUMSQ = UX * UX + UY * UY
    if (SUMSQ == 0): 
        break
    DX = (V * UY - U * UX) / SUMSQ
    X = X + DX
    DY = -(U * UY + V * UX) / SUMSQ
    Y = Y + DY
    if (abs(DY) + abs(DX) < 1e-5): 
        break
    ICT = ICT + 1
print("X, Y", X, Y)
print("IFIT", IFIT)
print("COF, XCOF: ", COF, XCOF)
for L in range(1, NXX + 1): 
    MT = KJ1 - L + 1
    print("L, MT: ", L, MT)
    TEMP = XCOF[MT - 1]
    XCOF[MT - 1] = COF[L - 1]
    COF[L - 1] = TEMP
print("COF, XCOF: ", COF, XCOF)
ITEMP = N
N = NX
NX = ITEMP
IFIT = 0
print(abs(Y / X) < 1e-4)
Y = 0.0
SUMSQ = 0.0
ALPHA = X
N = N - 1
COF[2 - 1] = COF[2 - 1] + ALPHA * COF[1 - 1]
for L in range(2, N + 1): 
    COF[L + 1 - 1] = COF[L + 1 - 1] + ALPHA * COF[L - 1] - SUMSQ * COF[L - 1]
print(COF)
ROOTI[N2 - 1] = Y
ROOTR[N2 - 1] = X
N2 = N2 + 1
print(SUMSQ, N)
print("ROOT: ", ROOTR, ROOTI)
print("__________________________________________________")
print("__________________________________________________")
XO = 0.00500101
YO = 0.01000101
IN = 0
X = XO
XO = -10.0 * YO
YO = -10.0 * X
X = XO
Y = YO
ICT = 0
IN = IN + 1
while (ICT < 500): 
    UX = 0.0
    UY = 0.0
    V = 0.0
    YT = 0.0
    XT = 1.0
    U = COF[N + 1 - 1]
    for I in range(1, N + 1): 
        L = N - I + 1
        XT2 = X * XT - Y * YT
        YT2 = X * YT + Y * XT
        U = U + COF[L - 1] * XT2
        V = V + COF[L - 1] * YT2
        FI = I
        UX = UX + FI * XT * COF[L - 1]
        UY = UY - FI * YT * COF[L - 1]
        XT = XT2
        YT = YT2
    SUMSQ = UX * UX + UY * UY
#    print(SUMSQ)
#    print(X, Y)
    if (SUMSQ == 0): 
        break
    DX = (V * UY - U * UX) / SUMSQ
    X = X + DX
    DY = -(U * UY + V * UX) / SUMSQ
    Y = Y + DY
    if (abs(DY) + abs(DX) < 1e-5): 
        break
    ICT = ICT + 1
print("COF, XCOF: ", COF, XCOF)
for L in range(1, NXX + 1): 
    MT = KJ1 - L + 1
    print("L, MT: ", L, MT)
    TEMP = XCOF[MT - 1]
    XCOF[MT - 1] = COF[L - 1]
    COF[L - 1] = TEMP
print("COF, XCOF: ", COF, XCOF)
ITEMP = N
N = NX
NX = ITEMP
print(IFIT)
IFIT = 1
XPR = X
YPR = Y
while ICT < 500: 
    UX = 0.0
    UY = 0.0
    V = 0.0
    YT = 0.0
    XT = 1.0
    U = COF[N + 1 - 1]
    print(U)
    for I in range(1, N + 1): 
        L = N - I + 1
        XT2 = X * XT - Y * YT
        YT2 = X * YT + Y * XT
        U = U + COF[L - 1] * XT2
        V = V + COF[L - 1] * YT2
        FI = I
        UX = UX + FI * XT * COF[L - 1]
        UY = UY - FI * YT * COF[L - 1]
        XT = XT2
        YT = YT2
    SUMSQ = UX * UX + UY * UY
    if (SUMSQ == 0): 
        break
    DX = (V * UY - U * UX) / SUMSQ
    X = X + DX
    DY = -(U * UY + V * UX) / SUMSQ
    Y = Y + DY
    if (abs(DY) + abs(DX) < 1e-5): 
        break
    ICT = ICT + 1
print("X, Y", X, Y)
print("IFIT", IFIT)
print("COF, XCOF: ", COF, XCOF)
for L in range(1, NXX + 1): 
    MT = KJ1 - L + 1
    print("L, MT: ", L, MT)
    TEMP = XCOF[MT - 1]
    XCOF[MT - 1] = COF[L - 1]
    COF[L - 1] = TEMP
print("COF, XCOF: ", COF, XCOF)
ITEMP = N
N = NX
NX = ITEMP
IFIT = 0
print(abs(Y / X) < 1e-4)
Y = 0.0
SUMSQ = 0.0
ALPHA = X
N = N - 1
COF[2 - 1] = COF[2 - 1] + ALPHA * COF[1 - 1]
for L in range(2, N + 1): 
    COF[L + 1 - 1] = COF[L + 1 - 1] + ALPHA * COF[L - 1] - SUMSQ * COF[L - 1]
print(COF)
ROOTI[N2 - 1] = Y
ROOTR[N2 - 1] = X
N2 = N2 + 1
print(SUMSQ, N)
print("ROOT: ", ROOTR, ROOTI)
print("__________________________________________________")
# Out:
# ('COF: ', [0.0, 0, 0, 0, 0])
# ('COF: ', [1, 0, -13, 0, 36.0])
# __________________________________________________
# ('COF, XCOF: ', [1, 0, -13, 0, 36.0], [36.0, 0, -13, 0, 1])
# ('L, MT: ', 1, 5)
# ('L, MT: ', 2, 4)
# ('L, MT: ', 3, 3)
# ('L, MT: ', 4, 2)
# ('L, MT: ', 5, 1)
# ('COF, XCOF: ', [1, 0, -13, 0, 36.0], [36.0, 0, -13, 0, 1])
# 0
# ('X, Y', -2.9999999999999996, 3.527785968148365e-26)
# ('IFIT', 1)
# ('COF, XCOF: ', [1, 0, -13, 0, 36.0], [36.0, 0, -13, 0, 1])
# ('L, MT: ', 1, 5)
# ('L, MT: ', 2, 4)
# ('L, MT: ', 3, 3)
# ('L, MT: ', 4, 2)
# ('L, MT: ', 5, 1)
# ('COF, XCOF: ', [1, 0, -13, 0, 36.0], [36.0, 0, -13, 0, 1])
# True
# [1, -2.9999999999999996, -4.000000000000002, 12.000000000000004, 36.0]
# (0.0, 3)
# ('ROOT: ', array([-3.,  0.,  0.,  0.]), array([ 0.,  0.,  0.,  0.]))
# __________________________________________________
# __________________________________________________
# ...

# %%
numpy.polynomial.polynomial.polyroots((36, 0, -13, 0, 1))
# Out:
# array([-3., -2.,  2.,  3.])

# %%
numpy.polynomial.polynomial.polyroots((83, -278, 720, -238, 120))
# Out:
# array([ 0.20146262-0.30271712j,  0.20146262+0.30271712j,
#         0.79020404-2.14629132j,  0.79020404+2.14629132j])

# %%
imp.reload(ER)
COF = numpy.array([1., 2])
X = 1
NX = 1
NXX = 1
Y = 1
SUMSQ = 0
ALPHA = 0
M = N = 1
(U, X, Y, SUMSQ, N, DX, DY) = ER.POLRT_eval_pol_and_deriv(COF, X, Y, SUMSQ, N)
print(U, X, Y, SUMSQ, N, DX, DY)
# Out:
# (1, -2.0, 0.0, 1.0, 1, -3.0, -1.0)
